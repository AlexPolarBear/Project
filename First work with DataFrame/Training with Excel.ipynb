# %%
import pandas as pd
import numpy as np
import names as n

# %%
pd.read_excel('Data1.xlsx')
# Out:
#    Unnamed: 0       Имя    Фамилия  Возраст  № выступления  Баллы  \
# 0           1  Lucienne    Hopkins        9              7     20
# 1           2   Annette      Doyle       13              5     40
# 2           3   Carolyn    Almanza       13             10     47
# 3           4     Susie     Snyder        8              8     55
# 4           5    Luella     Linton        7              9     55
# 5           6     Ilene    Hibbler       10              3     56
# 6           7     Lyman    Jackson       18              1     64
# 7           8     Anita       Paya       13              6     96
# 8           9     Corey       Ward       13              2     96
# 9          10    Marion  Rodriguez       14              4     98
#
#    Призовое место           Телефон
# 0              10  +7(268)865-27-26
# 1               9  +7(137)886-83-57
# 2               8  +7(335)474-30-58
# 3               7  +7(211)416-55-26
# 4               6  +7(840)979-52-64
# 5               5  +7(773)361-83-74
# 6               4  +7(767)697-26-53
# 7               3  +7(685)290-99-86
# 8               2  +7(635)743-81-45
# 9               1  +7(227)475-46-19

# %%
index = np.arange(1, 11)

frame = {'Имя': [n.get_first_name() for i in range(len(index))],
        'Фамилия': [n.get_last_name() for i in range(len(index))],
        'Возраст': [np.random.randint(5,20) for i in range(len(index))]}

frame['№ выступления'] = []
while len(frame['№ выступления']) != len(index):
    for i in range(len(index)):
        k = np.random.randint(i,11)
        if k not in frame['№ выступления'] and k != 0:
            frame['№ выступления'].append(k)
        
frame['Баллы'] = [np.random.randint(20,100) for i in range(len(index))]

frame['Призовое место'] = []
k = 10
p = 11
frame['Баллы'].sort()
for i in range(len(frame['Баллы'])):
    if k <= frame['Баллы'][i]:
        k = frame['Баллы'][i]
        p -= 1
        frame['Призовое место'].append(p)
        
frame['Телефон'] = [("+7" + "(" + str(np.random.randint(100, 1000)) + ")" + str(np.random.randint(100, 1000)) + "-" + str(np.random.randint(10, 100)) + "-" + str(np.random.randint(10, 100))) for i in range(len(index))]

df = pd.DataFrame(frame, index)

df.to_excel('Data2.xlsx')

# %%
df.sort_values(by = 'Призовое место')
# Out:
#           Имя      Фамилия  Возраст  № выступления  Баллы  Призовое место  \
# 10      Cindy         Rose        7              1     80               1
# 9     Jeffrey      Oconnor        5              6     68               2
# 8    Patricia       Barker       15              9     51               3
# 7   Salvatore         Boyd        5              8     49               4
# 6        Jose        Woods        5              7     49               5
# 5       Carol  Shinabarger       11              4     47               6
# 4     Jeffrey     Mcfarlin       17              5     40               7
# 3       Linda       Howell       14              2     37               8
# 2      Joshua         Cook       13             10     32               9
# 1      Judith         Rake       14              3     20              10
#
#              Телефон
# 10  +7(293)974-79-43
# 9   +7(622)994-67-23
# 8   +7(349)666-56-38
# 7   +7(306)807-65-90
# 6   +7(452)646-77-62
# 5   +7(505)761-75-89
# 4   +7(877)213-29-95
# 3   +7(986)858-41-69
# 2   +7(709)694-76-57
# 1   +7(430)164-63-90

# %%
df_1 = pd.read_excel('Data1.xlsx')
df_2 = pd.read_excel('Data2.xlsx')
df['Compare'] = df_1['Баллы'] <= df_1['Баллы']

# %%
df
# Out:
#           Имя      Фамилия  Возраст  № выступления  Баллы  Призовое место  \
# 1      Judith         Rake       14              3     20              10
# 2      Joshua         Cook       13             10     32               9
# 3       Linda       Howell       14              2     37               8
# 4     Jeffrey     Mcfarlin       17              5     40               7
# 5       Carol  Shinabarger       11              4     47               6
# 6        Jose        Woods        5              7     49               5
# 7   Salvatore         Boyd        5              8     49               4
# 8    Patricia       Barker       15              9     51               3
# 9     Jeffrey      Oconnor        5              6     68               2
# 10      Cindy         Rose        7              1     80               1
#
#              Телефон Compare
# 1   +7(430)164-63-90    True
# 2   +7(709)694-76-57    True
# 3   +7(986)858-41-69    True
# 4   +7(877)213-29-95    True
# 5   +7(505)761-75-89    True
# 6   +7(452)646-77-62    True
# 7   +7(306)807-65-90    True
# 8   +7(349)666-56-38    True
# 9   +7(622)994-67-23    True
# 10  +7(293)974-79-43     NaN
